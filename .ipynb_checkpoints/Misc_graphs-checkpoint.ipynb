# %%
# importing libraries
import pandas as pd # importing, data manipulation, subsetting
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mno
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# reading in the csv file 
data = pd.read_csv("US HOMOCIDE REPORT.csv")
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# replacing blanks with zeros
# make a copy of the original data to keep it safe
data2 = data.copy()

# replace blank strings with zeros
data2['Perpetrator Age'] = data2['Perpetrator Age'].replace(" ", 0)

# format them as integers
data2['Perpetrator Age'] = data2['Perpetrator Age'].astype(str).astype(int)

# it worked
#data2["Perpetrator Age"].unique()

# %%
data2.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %%
sns.catplot(data=data2, kind='bar', x='Victim Sex',y='Victim Age',hue='Victim Race',ci=None)

# %%
sns.catplot(data=data2, kind='bar', x='Perpetrator Sex',y='Perpetrator Age',hue='Perpetrator Race',ci=None)

# %%
data2.describe()
# Out:
#           Record ID           Year       Incident     Victim Age  \
# count  638454.00000  638454.000000  638454.000000  637480.000000
# mean   319227.50000    1995.801102      22.967924      33.562204
# std    184305.93872       9.927693      92.149821      17.792594
# min         1.00000    1980.000000       0.000000       0.000000
# 25%    159614.25000    1987.000000       1.000000      22.000000
# 50%    319227.50000    1995.000000       2.000000      30.000000
# 75%    478840.75000    2004.000000      10.000000      42.000000
# max    638454.00000    2014.000000     999.000000      99.000000
#
#        Perpetrator Age   Victim Count  Perpetrator Count
# count    638454.000000  638454.000000      638454.000000
# mean         20.322665       0.123334           0.185224
# std          17.886846       0.537733           0.585496
# min           0.000000       0.000000           0.000000
# 25%           0.000000       0.000000           0.000000
# ...

# %%
# should we encode?
# to

# %%
# Out:
#                    Record ID      Year  Incident  Victim Age  Perpetrator Age  \
# Record ID           1.000000  0.997286  0.116943   -0.021948        -0.031138
# Year                0.997286  1.000000  0.124125   -0.020022        -0.028450
# Incident            0.116943  0.124125  1.000000   -0.004339        -0.026063
# Victim Age         -0.021948 -0.020022 -0.004339    1.000000         0.144682
# Perpetrator Age    -0.031138 -0.028450 -0.026063    0.144682         1.000000
# Victim Count        0.026973  0.026765  0.001781   -0.021997         0.026555
# Perpetrator Count   0.056755  0.055959  0.001951   -0.032754         0.008878
#
#                    Victim Count  Perpetrator Count
# Record ID              0.026973           0.056755
# Year                   0.026765           0.055959
# Incident               0.001781           0.001951
# Victim Age            -0.021997          -0.032754
# Perpetrator Age        0.026555           0.008878
# ...

# %%
data2[(data2["State"]=='New York') & (data2["Crime Solved"]=='Yes')].count()
# Out:
# Record ID                26656
# Agency Code              26656
# Agency Name              26656
# Agency Type              26656
# City                     26656
# State                    26656
# Year                     26656
# Month                    26656
# Incident                 26656
# Crime Type               26656
# Crime Solved             26656
# Victim Sex               26656
# Victim Age               26656
# Victim Race              26656
# Victim Ethnicity         26656
# Perpetrator Sex          26656
# Perpetrator Age          26656
# Perpetrator Race         26656
# Perpetrator Ethnicity    26656
# Relationship             26656
# Weapon                   26656
# Victim Count             26656
# Perpetrator Count        26656
# Record Source            26656
# dtype: int64

# %%
ct_data = data2[(data2["State"]=='Connecticut') & (data2["City"])]

# %%
print('Number of data points: ',4896 * 24)
# Out:
# Number of data points:  117504

# %%
ct_data = ct_data.reset_index()
ct_data = ct_data.drop(columns = ['index'], axis=1)

# %%
ct_data.head()
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City  \
# 0       4856     CT00004        Avon  Municipal Police   Hartford
# 1       4857     CT00014    Branford  Municipal Police  New Haven
# 2       4858     CT00015  Bridgeport  Municipal Police  Fairfield
# 3       4859     CT00015  Bridgeport  Municipal Police  Fairfield
# 4       4860     CT00015  Bridgeport  Municipal Police  Fairfield
#
#          State  Year      Month  Incident              Crime Type  ...  \
# 0  Connecticut  1980  September         1  Murder or Manslaughter  ...
# 1  Connecticut  1980     August         1  Murder or Manslaughter  ...
# 2  Connecticut  1980    January         1  Murder or Manslaughter  ...
# 3  Connecticut  1980    January         2  Murder or Manslaughter  ...
# 4  Connecticut  1980   February         1  Murder or Manslaughter  ...
#
#   Victim Ethnicity Perpetrator Sex  Perpetrator Age Perpetrator Race  \
# ...

# %% [markdown]
# ## Country Growth

# %%
country_incidences = data2.groupby('Year')['Incident'].agg('count')
country_incidences = country_incidences.reset_index()

# %%
country_inc = sns.lineplot(data=country_incidences, x='Year',y='Incident')
country_inc.set_title("USA Homicides per year 1980-2014")
# Out:
# Text(0.5, 1.0, 'USA Homicides per year 1980-2014')

# %% [markdown]
# ## State that deserves it

# %%
florida = data2[data2['State']=='Florida']
florida_2014 = florida[florida['Year']==2014]

# %%
state_incidences = data2.groupby(['State','Year'])['Incident'].agg('count')
state_incidences = state_incidences.reset_index()

state_incidences_2014 = state_incidences[state_incidences['Year']==2014].reset_index()
state_incidences
state_incidences_pivot = state_incidences.pivot(index='Year',columns='State',values='Incident')

# %% [markdown]
# ## ADD HOW MUCH INFO IS NOT REPORTED

# %%
state_incidences_2014 = state_incidences[state_incidences['Year'] == 2014]
state_incidences_2014 = state_incidences_2014.reset_index().drop('index',axis=1)
sns.catplot(data=state_incidences_2014,kind='bar',x='State',y='Incident')

# %% [markdown]
# ## PER 100,000 rate 2014

# %%
state_pop = pd.read_csv('statepop2014.csv')

# %%
state_incidences_2014['Population'] = state_pop['Population']
state_incidences_2014['Murder Per Capita'] = ((state_incidences_2014['Incident']/state_incidences_2014['Population']
                                              )*100000).round(2)
state_incidences_2014_top10 = state_incidences_2014.sort_values('Murder Per Capita',ascending=False).head(10)
percapita_states = sns.catplot(data=state_incidences_2014_top10,x='State',y='Murder Per Capita',kind='bar',aspect=3)
plt.title('Top 10 State Most Murders by Capita')
# Out:
# Text(0.5, 1, 'Top 10 State Most Murders by Capita')

# %% [markdown]
# ## Least murders per state

# %%
least_state_murd = state_incidences_2014.sort_values(by='Murder Per Capita').head(10)
least_state_murd_plot = sns.catplot(data=least_state_murd,x='State',y='Murder Per Capita',kind='bar',aspect=3)
plt.title('Top 10 Lowest State Most Murders by Capita')
# Out:
# Text(0.5, 1, 'Top 10 Lowest State Most Murders by Capita')

# %% [markdown]
# ## District of Columbia

# %%
dist_colombia = data2[data2['State']=='District of Columbia']
dist_colombia = dist_colombia.reset_index().drop('index',axis=1)

# %%
dist_colombia_years = dist_colombia.groupby('Year')['Incident'].agg('count')
sns.lineplot(data = dist_colombia_years)

# %%
## month

# %%
dist_colombia_2014 = dist_colombia[dist_colombia['Year']==2014]
dist_colombia_2014['Month'].value_counts().plot(kind='bar')

# %%
labels = dist_colombia_2014['Month'].astype('category').cat.categories.tolist()
counts = dist_colombia_2014['Month'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = dist_colombia_2014['Perpetrator Age'].astype('category').cat.categories.tolist()
counts = dist_colombia_2014['Perpetrator Age'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
sns.distplot(dist_colombia_2014['Perpetrator Age'])

# %%
sns.distplot(dist_colombia_2014['Victim Age'])

# %%
dist_colombia_2014['Victim Age'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# ## louisiana

# %%
louisiana = data2[data2['State']=='Louisiana']
louisiana = louisiana.reset_index().drop('index',axis=1)

# %%
louisiana['City'].unique()
# Out:
# array(['Acadia', 'Allen', 'Ascension', 'Assumption', 'Avoyelles',
#        'Beauregard', 'Bossier', 'Caddo', 'Calcasieu', 'Caldwell',
#        'Claiborne', 'Concordia', 'East Baton Rouge', 'East Carroll',
#        'East Feliciana', 'Evangeline', 'Franklin', 'Grant', 'Iberia',
#        'Iberville', 'Jackson', 'Jefferson', 'Jefferson Davis',
#        'Lafayette', 'Lafourche', 'Lincoln', 'Livingston', 'Madison',
#        'Morehouse', 'Natchitoches', 'Ouachita', 'Plaquemines',
#        'Pointe Coupee', 'Rapides', 'St. Bernard', 'St. Charles',
#        'St. James', 'St. John the Baptist', 'St. Landry', 'St. Mary',
#        'St. Tammany', 'Tangipahoa', 'Terrebonne', 'Vermilion', 'Vernon',
#        'Washington', 'Webster', 'West Baton Rouge', 'Winn', 'Orleans',
#        'La Salle', 'Sabine', 'St. Helena', 'St. Martin', 'Union',
#        'West Carroll', 'Tensas', 'West Feliciana', 'De Soto', 'Richland',
#        'Red River', 'Catahoula', 'Bienville', 'Cameron'], dtype=object)

# %%
louisiana['City'].value_counts().head(10)
# Out:
# Orleans             7847
# East Baton Rouge    2472
# Jefferson           1700
# Caddo               1616
# Lafayette            464
# Rapides              438
# Calcasieu            438
# Ouachita             381
# St. Tammany          303
# Terrebonne           254
# Name: City, dtype: int64

# %%
orleans = louisiana[louisiana['City']=='Orleans']
orleans.groupby('Year')['Incident'].agg('count').plot()

# %%
labels = orleans['Perpetrator Age'].astype('category').cat.categories.tolist()
counts = orleans['Perpetrator Age'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
orleans.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %%
labels = orleans['Crime Solved'].astype('category').cat.categories.tolist()
counts = orleans['Crime Solved'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = orleans['Victim Age'].astype('category').cat.categories.tolist()
counts = orleans['Victim Age'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = orleans['Perpetrator Race'].astype('category').cat.categories.tolist()
counts = orleans['Perpetrator Race'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = orleans['Perp_age_group'].astype('category').cat.categories.tolist()
counts = orleans['Perp_age_group'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Perp_age_group'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-24e99f0c8b1e> in <module>
# ...

# %%
labels = orleans['Month'].astype('category').cat.categories.tolist()
counts = orleans['Month'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = orleans['Relationship'].astype('category').cat.categories.tolist()
counts = orleans['Relationship'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
labels = orleans['Weapon'].astype('category').cat.categories.tolist()
counts = orleans['Weapon'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
orleans[['Relationship', 'Perpetrator Race', 'Victim Race','Weapon']].corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## City

# %%
city_incidences = data2.groupby(['City','Year'])['Incident'].agg('count')
city_incidences = city_incidences.reset_index()
top_2014 = city_incidences[city_incidences['Year']==2014]
top_2014 = top_2014.groupby('City')['Incident'].agg('sum')
top_2014 = top_2014.reset_index()
top_2014.sort_values('Incident',ascending=False).head()
# Out:
#             City  Incident
# 522  Los Angeles       572
# 213         Cook       439
# 951        Wayne       376
# 382       Harris       359
# 629     New York       345

# %%
# do like a bar plot/ per capita?

# %%
# POVERTY + unemployment rate

# %%
data2.columns

# %% [markdown]
# ## Nunality matrix

# %%
nunality = data2.copy()

vic_age_limit = nunality["Victim Age"] > 99
data2["Victim Age"][vic_age_limit] = np.nan

perp_age_null = nunality['Perpetrator Age'] == 0 
nunality["Perpetrator Age"][perp_age_null] = np.nan

vic_sex_null = nunality['Victim Sex'] == 'Unknown' 
nunality["Victim Sex"][vic_sex_null] = np.nan

vic_Race_null = nunality['Victim Race'] == 'Unknown' 
nunality["Victim Race"][vic_Race_null] = np.nan

vic_Ethnicity_null = nunality['Victim Ethnicity'] == 'Unknown' 
nunality["Victim Ethnicity"][vic_Ethnicity_null] = np.nan

perp_sex_null = nunality['Perpetrator Sex'] == 'Unknown' 
nunality["Perpetrator Sex"][perp_sex_null] = np.nan

perp_Race_null = nunality['Perpetrator Race'] == 'Unknown' 
nunality["Perpetrator Race"][perp_Race_null] = np.nan


perp_Ethnicity_null = nunality['Perpetrator Ethnicity'] == 'Unknown' 
nunality["Perpetrator Ethnicity"][perp_Ethnicity_null] = np.nan


relationship_null = nunality['Relationship'] == 'Unknown' 
nunality['Relationship'][relationship_null] = np.nan


weapon_null = nunality['Weapon'] == 'Unknown' 
nunality['Weapon'][weapon_null] = np.nan
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
mno.matrix(nunality, figsize = (20, 6))

# %% [markdown]
# ## % Missing

# %%
nunality_check = nunality.isna().sum()
nunality_pct = nunality_check/len(nunality)
nunality_pct_times = nunality_pct * 100
nunality_pct_times
# Out:
# Record ID                 0.000000
# Agency Code               0.000000
# Agency Name               0.000000
# Agency Type               0.000000
# City                      0.000000
# State                     0.000000
# Year                      0.000000
# Month                     0.000000
# Incident                  0.000000
# Crime Type                0.000000
# Crime Solved              0.000000
# Victim Sex                0.154122
# Victim Age                0.000000
# Victim Race               1.045651
# Victim Ethnicity         57.686693
# Perpetrator Sex          29.816557
# Perpetrator Age          33.883099
# Perpetrator Race         30.706519
# Perpetrator Ethnicity    69.920464
# Relationship             42.761577
# Weapon                    5.198808
# Victim Count              0.000000
# Perpetrator Count         0.000000
# Record Source             0.000000
# dtype: float64

# %%
state_incidences_2014.sort_values('Murder Per Capita').head()

# %%
labels = data2['Relationship'].astype('category').cat.categories.tolist()
counts = data2['Relationship'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %% [markdown]
# ## CT Growth

# %%
ct_incidences = ct_data.groupby('Year')['Incident'].agg('sum')
ct_incidences = ct_incidences.reset_index()

# %%
# Growth of incidences per year 
# Compare it to country average

# %%
sns.lineplot(data=ct_incidences, x='Year',y='Incident')

# %%
## need the rate

# %%
country_incidences['Dataset'] = 'Country'
ct_incidences['Dataset'] = 'CT'
c = pd.concat([country_incidences,ct_incidences])
sns.lineplot(data=c, x='Year',y='Incident',hue='Dataset')

# %% [markdown]
# ## Distribution of incidences

# %%
sns.distplot(ct_incidences['Incident'])

# %%
data2.groupby('Month')['Incident'].describe()
# Out:
#              count       mean        std  min  25%  50%   75%    max
# Month
# April      51209.0  22.624441  92.312039  0.0  1.0  2.0   9.0  999.0
# August     58072.0  23.607694  90.392191  0.0  1.0  2.0  11.0  999.0
# December   55187.0  21.268505  87.773651  0.0  1.0  2.0   9.0  999.0
# February   46079.0  21.292671  91.420321  0.0  1.0  2.0   8.0  999.0
# January    52928.0  22.770046  92.585177  0.0  1.0  2.0   9.0  998.0
# July       58696.0  24.278401  92.128087  1.0  1.0  2.0  11.0  998.0
# June       53662.0  23.399538  93.500636  1.0  1.0  2.0  10.0  996.0
# March      51444.0  22.326996  91.049791  0.0  1.0  2.0   9.0  998.0
# May        53394.0  23.660467  95.623501  0.0  1.0  2.0  10.0  999.0
# November   50016.0  22.375460  91.928013  0.0  1.0  2.0   9.0  999.0
# October    53650.0  23.870568  94.461375  0.0  1.0  2.0  10.0  999.0
# September  54117.0  23.688748  92.471087  0.0  1.0  2.0  10.0  999.0

# %%
data2['Incident'].max()
# Out:
# 999

# %%
d = data2.groupby(['Year','Month'])['Incident'].agg('mean').reset_index()
dd = d[d['Year']==2014]
dd.plot(x='Month',y='Incident',kind='bar')

# %%
ct_data_2014 = ct_data[ct_data["Year"]== 2014]
ct_data_2014 = ct_data_2014.reset_index()
ct_data_2014 = ct_data_2014.drop(columns = ['index'], axis=1)

# %%
ct_data_2014.head()

# %% [markdown]
# ## Growth

# %%
data2[(data2["State"]=='Connecticut') & (data2["City"])]

# %%
## Categories

# %%
# a complex function

def my_perp_age(x):
    if x <= 21:
        return 'child'
    if x > 60:
        return 'elder'
    else:
        return 'adult'

# %%
data2["Perp_age_group"] = data2['Perpetrator Age'].apply(lambda x: my_perp_age(x))

# %%
labels = data2['Perp_age_group'].astype('category').cat.categories.tolist()
counts = data2['Perp_age_group'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
y_2014 = data2[data2['Year']==2014]
labels = y_2014['Month'].astype('category').cat.categories.tolist()
counts = y_2014['Month'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True) #autopct is show the % on plot
ax1.axis('equal')
plt.show()

# %%
data2.columns

# %%
data2['Relationship'].unique()

# %%
replace_map = {'Relationship': {'Acquaintance': 1, 'Unknown': 2, 'Wife': 3, 'Stranger': 4,
                                  'Girlfriend': 5, 'Ex-Husband': 6, 'Brother': 7 , 'Stepdaughter': 8 , 'Husband': 9,
                                'Sister': 10,'Friend': 11,'Family': 1, 'Neighbor': 2, 'Father': 3, 'Stranger': 4,
                                  'Girlfriend': 5, 'Ex-Husband': 6, 'Brother': 7 , 'Stepdaughter': 8 , 'Husband': 9,
                                'Sister': 10,'Friend': 11}}

# %%
# How to categorize family
# By family, outside family
# family, relationship, professional
# close family, outer family, work, not-family

# %%
# Data to plot
labels = 'Solved Crimes', 'Unsolved Crimes'
sizes = [448172/638454, 190282/638454]
colors = ['yellowgreen','lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
data2[(data2["Crime Solved"]=="No") & (data2["Relationship"]=='Unknown')].count()

# %%
objects = ('Relationship', 'Victim Ethnicity', 'Victim Age', 'Perpetrator Ethnicity', 'Perpetrator Age', 'Unsolved Crimes')
y_pos = np.arange(len(objects))
performance = [178121,113271,1025,190036,189628,190282]

plt.barh(y_pos, performance,align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Number of Incidences')
plt.title('Unsolved Murders Related to Missing Data')

# %% [markdown]
# ## Murder still happened

# %%
# Growth over years
incident_mention = data2.groupby('Year')['Incident'].agg('count')
incident_mention.plot()

# %%
# Growth over years
incident_mention = data2.groupby('Year')['Incident'].agg('sum')
incident_mention.plot()

# %% [markdown]
# # MARK THE FINANCIAL CRISIS

# %%
incident_sum_year = data2.groupby('Year')['Incident'].agg('count')
incident_sum_year.plot()
plt.axvspan(2000,2002,facecolor='g', alpha=0.5)
plt.axvspan(2007,2009,facecolor='g', alpha=0.5)

# %% [markdown]
# ## Most murderous states

# %%
data2['State'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %% [markdown]
# ## Least Murderes States

# %%
data2['State'].value_counts().sort_values(ascending=False).tail(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %%
data2['Month'].value_counts().plot(kind='bar')
plt.title("Murders by Month")

# %% [markdown]
# ## Errors

# %%
# replacing perpetrators under the age 6 with NAN
# search for ages below 6
# This returns True/False
data3 = data2.copy()
perp_age_mean = data3["Perpetrator Age"] < 6

# replace them with nan values for that column
data3["Perpetrator Age"][perp_age_mean] = np.nan

# drop the na row values (results becomes a float for only that column becasue of numpy)
# results have to be assigned otherwise it doesn't updates
data3 = data3.dropna()

# reset the index that now jumps from missing values e.g. 1, 100,102 etc.
data3 = data3.reset_index(drop=True)

# convert the column back to integers
data3["Perpetrator Age"] = data3["Perpetrator Age"].astype(int)
# display the df information
# we got rid off 216,454 values
#data2.info()

#getting the mean age
mean_perp_age = data3["Perpetrator Age"].mean().round()

# %% [markdown]
# ## Perp. Age mean

# %%
fill_perpage_mean = data2["Perpetrator Age"] < 6
data2["Perpetrator Age"][fill_perpage_mean] = np.nan
data2["Perpetrator Age"] = data2["Perpetrator Age"].fillna(mean_perp_age)

# %% [markdown]
# ## Victim Age

# %%
data4 = data.copy()
vic_age_limit = data4["Victim Age"] > 99
data4["Victim Age"][vic_age_limit] = np.nan
data4 = data4.dropna()
data4 = data4.reset_index(drop=True)
data4["Victim Age"] = data4["Victim Age"].astype(int) 
vic_age_mean = data4["Victim Age"].mean().round()
vic_age_mean

# %%
fill_vic_mean = data2["Victim Age"] > 99 
data2["Victim Age"][fill_vic_mean] = np.nan
data2["Victim Age"] = data2["Victim Age"].fillna(vic_age_mean)

# %%
# predict with machine learning for the unknows, we can fill but that will not be accurate
# we could then just predict approx what would be

# %%
data2['Relationship'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Murders by Relationship 1980-2014")

# %%
data2['Weapon'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %% [markdown]
# ## Pie Charts for this

# %%
data2['Perpetrator Age'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %%
data2['Victim Age'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %%
data2['Perpetrator Ethnicity'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("10 States with Most Murders 1980-2014")

# %% [markdown]
# ## Age group
#     - >10, 11-19, 20-29, 30-39,40-49,50-59
# ## Close Family member

# %%
def my_age(x):
    if x <21:
        return 'child'
    if x > 60:
        return 'elder'
    else:
        return 'adult'

# %%
# so we have lots of data that we do not because we do not know the perpetrator 
# delete all the unknowns and we could perhaps learn what data will tell us with machine learning 
# Better than to not know 

# what causes the murdering to increase 
# chances you get murdered 
# per capita something

# %%
# replacing perpetrators under the age 6 with NAN
# search for ages below 6
# This returns True/False
under_6 = data2["Perpetrator Age"] < 6

# replace them with nan values for that column
data2["Perpetrator Age"][under_6] = np.nan

# drop the na row values (results becomes a float for only that column becasue of numpy)
# results have to be assigned otherwise it doesn't updates
data2 = data2.dropna()

# reset the index that now jumps from missing values e.g. 1, 100,102 etc.
data2 = data2.reset_index(drop=True)

# convert the column back to integers
data2["Perpetrator Age"] = data2["Perpetrator Age"].astype(int)

# display the df information
# we got rid off 216,454 values
#data2.info()

# %%
# perpetrator age without any unknowns 
data2["Perpetrator Age"].mean()

# %%
data2[(data2["Crime Solved"]=='No') & (data2["Relationship"]=='Unknown')].count()

# %%
# drop the 0 
#
